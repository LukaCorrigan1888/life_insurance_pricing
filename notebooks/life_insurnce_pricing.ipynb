# %%
from life_pricing.mortality import *

# %%
# Mortality assumption configuration

confi = GompertzConfig(0.0005, 1.08)
